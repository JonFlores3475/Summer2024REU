# %%
import pandas as pd
import numpy as np

# %%
Accuracy = pd.read_csv('data/label_skew/inverted_gradient/fl_usps/Weight/FedProx/FedProxAtroposUSPSSeed123/in_domain_mean_acc.csv')

# %%
meanAccuracy = Accuracy.mean(axis=1)

# %%
print(meanAccuracy)
# Out:
# 0    93.7927
# dtype: float64
